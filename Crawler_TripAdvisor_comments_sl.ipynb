# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
import time
import random
import os

if not os.path.exists('./restComments'):
    os.mkdir('./restComments')

url='https://www.tripadvisor.com.tw/Restaurants-g293913-Taipei.html'

userAgent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36 Edg/90.0.818.56'
headers = {'User-Agent':userAgent}

browser=webdriver.Chrome()

for i in range(1):
    browser.get(url)
    res=browser.page_source
    soup=BeautifulSoup(res, 'html.parser')

    for restTags in soup.select('a[class="_15_ydu6b"]'):
        try:
            restUrl='https://www.tripadvisor.com.tw'+restTags['href']            
            k=1
            while k!=0:
                try:
                    browser.get(restUrl)
                    restRes=browser.page_source
                    restSoup=BeautifulSoup(restRes, 'html.parser')
                    restName=restSoup.select('h1[class="_3a1XQ88S"]')[0].text
                    for commentList in restSoup.select('div[class="rev_wrap ui_columns is-multiline"]'):
                        commenter=commentList.select('div[class="info_text pointer_cursor"]')[0].text
                        commentRating=commentList.select('div[class="ui_column is-9"] span')[0]['class'][1].split('bubble_')[-1]
                        commentTitle=commentList.select('span[class="noQuotes"]')[0].text
                        comment=commentList.select('p[class="partial_entry"]')[0].text
#                         print(restName)
                        print(commenter)
#                         print(str(int(commentRating)/10))
#                         print(commentTitle)
#                         print(comment)
#                         print('------')
                        with open('./restComments/{}.txt'.format(restName), 'a', encoding='utf-8') as f:
                            f.write('評論帳號: '+commenter+'\n')
                            f.write('評論分數: '+str(int(commentRating)/10)+'\n')
                            f.write('評論標題: '+commentTitle+'\n')
                            f.write('評論內容: '+comment+'\n')
                            f.write('------'+'\n')
                    newRestUrl='https://www.tripadvisor.com.tw'+restSoup.select('a[class="nav next ui_button primary"]')[0]['href']
                    restUrl=newRestUrl
                    print('***Click 手動載入，' + restName + '留言第' + str(k+1) + '頁***')    
                    k=k+1
                    time.sleep(random.randint(4, 6))
                except:
                    k=0
                    print(restName + 'has no more comments')                        
        except IndexError:
            print(IndexError)
            break
        time.sleep(random.randint(1, 5))
        
    newUrl = 'https://www.tripadvisor.com'+soup.select('a[class="nav next rndBtn ui_button primary taLnk"]')[0]['href']
    url=newUrl
    
browser.close()
# Out:
# WYL1214
# Inouetomoo
# jizi0519
# Mike-Dai1995
# Ghost982
# LCK_of_Taiwan
# mouse1toto2
# katenishikata
# ninoayaya
# Alger_Chang
# ***Click 手動載入，W XYZ Bar留言第2頁***
# Jieziya
# AppleR20
# s24251162
# Jet805101
# lend505050
# ACloud33
# 294yang
# rosivdapirtylla
# EverJennyT
# ethan9011
# ***Click 手動載入，W XYZ Bar留言第3頁***
# Adrainhau
# E4231HM_
# Allysiasasa
# Kenjilondon
# Angela590804
# Sightseer60013230339
# Navigate405404
# LaraHung
# viviansyuan
# AngelababyChang
# ***Click 手動載入，W XYZ Bar留言第4頁***
# TeamdoubleA
# tikleee
# woopenny
# lend505050
# jacky42958
# ACloud33
# WilliamHoLuLu
# Seward0521
# kkeevviinn0128
# yang10833
# ***Click 手動載入，W XYZ Bar留言第5頁***
# angelmamama
# Noteeee
# dapassmazi
# MyMagg
# _T3203TG
# wendyliu117
# amyf265
# Joeydagger
# MeganChen37
# Dinoyou
# ***Click 手動載入，W XYZ Bar留言第6頁***
# abc1232672
# Zoey_yang123
# 1leslies
# polinshen
# ChenY759
# GeoJoey76
# Ken820104
# jimmylai_95
# 204gjo3m6
# 裴傑
# ***Click 手動載入，W XYZ Bar留言第7頁***
# yehsam23
# 峯
# squalllucky
# Gina_01307
# 抹茶Uli
# thnvhvhjttch
# XingEn_628
# CCP168
# Jacoblee0220
# light132145
# ***Click 手動載入，W XYZ Bar留言第8頁***
# sarawE8036XR
# Johnnyyu_93
# Lynn_LWH
# bullhsieh2015
# Sandy_Chang1213
# wayvivian
# Noteeee
# Emily11205
# Happiness807385
# foever23
# ***Click 手動載入，W XYZ Bar留言第9頁***
# hachu0
# hzlinggggg
# lindazbsnnsmsms
# EEmily0214
# Chris850335
# vito2411
# wayvivian
# Excursion384846
# Guide28030833383
# Ddddddddrrr
# ***Click 手動載入，W XYZ Bar留言第10頁***
# Bean7277
# dmopc
# Ieightthedogsheet
# Den274929z
# IreneLee1215
# Ted8245
# SourSoul
# tso3007376
# HsiangN2
# Alex890104
# ***Click 手動載入，W XYZ Bar留言第11頁***
# s_y_d_neyyyyyyyyyyy
# ki0528
# 丞焌 黃
# chenyitsen
# soraigi
# tokiork
# jack1306123321
# Polinwu0331
# Jimmy3490901
# fun0328
# ***Click 手動載入，W XYZ Bar留言第12頁***
# lmsss
# Amy0819Queen
# Passport03180068094
# Referrerpp
# yutangc14
# ICanMakeIt
# Umaslee299
# HoneyMilkY
# hsien2020
# Yuelong0910
# ***Click 手動載入，W XYZ Bar留言第13頁***
# JasonChen901116
# DerekChien18
# Cindyhahabutterfly
# Venture731969
# bossph
# Jennie-Hou
# Queenie T
# TsuTsu123
# 子安 李
# Getaway809200
# ***Click 手動載入，W XYZ Bar留言第14頁***
# hwamarry
# jacky2666716
# Kenjilondon
# Trip732720
# _W3009PH
# JackyKellen
# Kellen5186
# chiangpei
# Jfhdbdfndj
# chaoshihpo0603
# ***Click 手動載入，W XYZ Bar留言第15頁***
# JesseH1388
# mangell2015
# pingping0801
# tim15854
# Adventure807244
# coco賴可馨
# 763mattc
# Chocolate0625
# Wally_chen111
# u101001439
# ***Click 手動載入，W XYZ Bar留言第16頁***
# 仲博
# osnkd_w
# Boquanhuang
# isaachuang0801
# Ocargu
# Maplelinz
# Yuyangyuyang
# John34566
# Dream410355
# Leaf840325
# ***Click 手動載入，W XYZ Bar留言第17頁***
# andacyt
# Yuouoz
# showru
# Kevin404013
# peggylee0712
# JAN-HO168
# Chen-tsung-heng
# T6582HCchristine
# 71amandak
# Vian927
# ***Click 手動載入，W XYZ Bar留言第18頁***
# Xavierlin97
# 張繼正
# YukiH133
# Zuolon
# 翁子宏
# Laurent9266
# Trip805948
# Minga717
# 咻
# Momoo_0126
# ***Click 手動載入，W XYZ Bar留言第19頁***
# Compass803740
# raylinak476432
# jwujwu
# ChingChing915915
# shanbear0707
# max4r1
# Inspiration811193
# nuofuxika
# Yulun-Wu
# DayTrip429789
# ***Click 手動載入，W XYZ Bar留言第34頁***
# Albert-wen
# hen40307
# Wanderer27365626877
# AnnesC3
# Journey11611458622
# leejane881001
# evelynchu506
# Wander05424121361
# Happiness62262292560
# KYLEYEN
# ***Click 手動載入，W XYZ Bar留言第35頁***
# ervinchen0323
# Quest29211686298
# guluuu
# o7o7
# Sightsee827537
# Inspire827362
# Exploration827262
# Navigate827346
# Vacationer829079
# Storyteller824107
# ***Click 手動載入，W XYZ Bar留言第36頁***
# Trek420532
# Flyer824149
# Paradise823331
# Inspiration822939
# Global823107
# Navigator823124
# Excursion731684
# Vacationer821586
# Pathfinder820910
# Jamespax
# ***Click 手動載入，W XYZ Bar留言第37頁***
# Footprints821311
# Relax804202
# Escape821378
# Connector683624
# FrequentFlier459906
# Scenic819514
# tonysu159
# chliao1980
# 曉琦
# Jet393625
# ***Click 手動載入，W XYZ Bar留言第38頁***
# Getaway817147
# Dream817347
# Resort817741
# Happiness817807
# Navigator817557
# Freedom817610
# Discover815738
# enidyen0521
# LightPacker815401
# Sightsee815411
# ***Click 手動載入，W XYZ Bar留言第39頁***
# Dream815808
# Vacation463394
# Resort658856
# silvia85813
# TrailBlazer814448
# Roving813455
# ArashiY5
# TrailBlazer812688
# chingchih
# Coastal684915
# ***Click 手動載入，W XYZ Bar留言第40頁***
# OnAir258374
# Safari801616
# 怡萱 李
# Excursion800834
# LoveTravel810584
# janear h
# TangYunC
# satosi2016
# FarAway738033
# KaiL1022
# ***Click 手動載入，W XYZ Bar留言第41頁***
# Escape797982
# 曼萱 李
# Remus Y
# lydiahX7557LK
# Sightsee796469
# loz172
# 家緣 劉
# 厚紳 潘
# Sightsee785666
# GrandTour795592
# ***Click 手動載入，W XYZ Bar留言第42頁***
# Curious795296
# Journey793273
# Excursion792992
# JohnsonC464
# Sightsee785666
# Safari745557
# GaryW3801
# PoHsiangF2
# FarAway768556
# lo1622ve
# ***Click 手動載入，W XYZ Bar留言第43頁***
# Kelly0082
# Sabrina780103
# Trek766731
# AdiB874
# AdiB872
# ChuP81
# Meander803927
# Culture764523
# Vacationer383376
# 晏羽 劉
# ***Click 手動載入，W XYZ Bar留言第44頁***
# Trail764559
# AweiT3
# Trek764299
# Seaside809337
# ViviT335
# KaiTingC18
# GrandTour762180
# DanielC16014
# CarmanC
# GregW2739
# ***Click 手動載入，W XYZ Bar留言第45頁***
# Maruko L
# LinC959
# Hsiuchao
# Connector809382
# singlenoble
# Jennygoaroundworld
# OnAir671203
# wenshingl
# YilingH9
# 141minnac
# ***Click 手動載入，W XYZ Bar留言第46頁***
# Jennygoaroundworld
# Tour808995
# fxm8英國倫敦
# lordboots華盛頓州貝爾維尤
# Dido7英國倫敦
# sunjoe075新澤西州普林斯頓
# eioor123
# NorthStar474074
# en104yu138
# Expedition805793
# Chieh1121
# simonmi123
# Samshijr
# fo11863
# ***Click 手動載入，布娜飞比利时啤酒餐厅 台北市民店留言第2頁***
# ch570971400
# garitai
# Denismau0910
# thengtheng_97
# x038410276616x
# andyyeh20237
# kellysu07141995
# Vacation555611
# Candy02060424
# Cindy0423
# ***Click 手動載入，布娜飞比利时啤酒餐厅 台北市民店留言第3頁***
# Chi861217
# samanthapinyun
# Vans_chen
# Fjsjxjwjxs
# z85549
# Ywkwy25
# K24765290
# vin31107
# derek831030
# ERIC52300
# ***Click 手動載入，布娜飞比利时啤酒餐厅 台北市民店留言第4頁***
# Jillbaw
# bestsongs159
# GaiAn93
# hhh624588
# mrlopin
# 涂為禎
# YunyungLin
# Ppt1215
# Deebby0908
# carol811226
# ***Click 手動載入，布娜飞比利时啤酒餐厅 台北市民店留言第5頁***
# 布娜飞比利时啤酒餐厅 台北市民店has no more comments
# ted19960224
# imcyrusss
# yuhao850703
# tungjoting
# alex365099
# Mav_wu0227
# JUMBO0610
# RossChiang
# vilachiu0531
# _Q2303BV
# ***Click 手動載入，WOOBAR留言第2頁***
# Timwu96
# Cynthia_Shie
# 317idah
# AshleyH10610
# Roger_SK2X
# Discover667937
# _B2301SL
# carl77carl77
# Leoneskw
# Youngchy22
# ***Click 手動載入，WOOBAR留言第3頁***
# chinyenyang
# Kenglin1304
# D2412LV_
# sihannnnnnn
# KaiLoY
# 欣辰
# tim15854
# yunen L
# Kidkie
# shrhannnnn
# ***Click 手動載入，WOOBAR留言第4頁***
# minsha0101
# ChungH133
# megan123a
# 許育綸
# hehe1111111116
# szuyuchi
# CloudCccccccc
# Elsieeeeeesedeeeeeee
# BB0627
# amy3692
# ***Click 手動載入，WOOBAR留言第5頁***
# Elena0223
# Hsuan326
# Mark0118
# Jennyfann
# Sofia1234a
# Kellydalala
# berlinchoose
# circus1309
# PinH20
# Jesonnnnn
# ***Click 手動載入，WOOBAR留言第6頁***
# Chihweii
# Enfyszhu
# Naomiluo
# T5740GYclaireh
# TTHUANGTien
# Chadqwe
# ChloeC0409
# as56abc02
# Benliao1988
# Lululinsinju
# ***Click 手動載入，WOOBAR留言第7頁***
# VicPeng01
# jmaneats
# onugakoi
# Gau A
# tetsuchien
# Scenic387042
# huhhuhnini
# DayTrip809690
# Lu0811
# Mmi422
# ***Click 手動載入，WOOBAR留言第8頁***
# Expedition408524
# LeoChen0324
# tsujuifu
# s8508235
# Yui761216
# elinlin010
# sn00c
# evelynsmile
# EddieChen0509
# yu18
# ***Click 手動載入，WOOBAR留言第9頁***
# WOOBARhas no more comments
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-b96ea075fd09> in <module>
#      59             print(IndexError)
#      60             break
# ---> 61         time.sleep(random.randint(1, 5))
#      62
#      63     newUrl = 'https://www.tripadvisor.com'+soup.select('a[class="nav next rndBtn ui_button primary taLnk"]')[0]['href']
#
# KeyboardInterrupt:
