# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
import time
import random
import os

if not os.path.exists('./restComments'):
    os.mkdir('./restComments')

url='https://www.tripadvisor.com.tw/Restaurants-g293913-Taipei.html'

userAgent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36 Edg/90.0.818.56'
headers = {'User-Agent':userAgent}

browser=webdriver.Chrome()

for i in range(1):
    browser.get(url)
    res=browser.page_source
    soup=BeautifulSoup(res, 'html.parser')

    for restTags in soup.select('a[class="_15_ydu6b"]'):
        try:
            restUrl='https://www.tripadvisor.com.tw'+restTags['href']            
            k=1
            while k!=0:
                try:
                    browser.get(restUrl)
                    restRes=browser.page_source
                    restSoup=BeautifulSoup(restRes, 'html.parser')
                    restName=restSoup.select('h1[class="_3a1XQ88S"]')[0].text
                    for commentList in restSoup.select('div[class="rev_wrap ui_columns is-multiline"]'):
                        commenter=commentList.select('div[class="info_text pointer_cursor"]')[0].text
                        commentNum=commentList.select('span[class="badgeText"]')[0].text
                        if commentNum!="1則評論":
                            print('*****'+commenter)
                            commenterUrl='https://www.tripadvisor.com.tw/Profile/'+commenter
                            commenterRes=requests.get(commenterUrl, headers=headers)
                            commenterSoup=BeautifulSoup(commenterRes.text, 'html.parser')
                            for otherCommentList in commenterSoup.select('div[class="nMewIgXP ui_card section"]'):
                                otherRestName=otherCommentList.select('div[class="_2ys8zX0p ui_link"]')[0].text
                                if otherRestName!=restName:
                                    otherRestLocation=otherCommentList.select('div[class="_7JBZK6_8 _20BneOSW"] span')[0].text
                                    otherRestRating=otherCommentList.select('div[class="_1VhUEi8g _2K4zZcBv"] span')[0]['class'][1].split('bubble_')[-1]
                                    otherCommTitle=otherCommentList.select('div[class="_3IEJ3tAK _2K4zZcBv"]')[0].text
                                    otherComment=otherCommentList.select('div[class="_133ThCYf"] q')[0].text
                                    otherRestUrl='https://www.tripadvisor.com.tw'+otherCommentList.select('div[class="_2X5tM2jP _2RdXRsdL _1gafur1D"] div a')[0]['href']
                                    print(otherRestName)
                                    print(otherRestLocation)
                                    print(str(int(otherRestRating)/10))
                                    print(otherCommTitle)
                                    print(otherComment)
                                    print(otherRestUrl)
                                    print('------')
                                    time.sleep(random.randint(1, 5))
                                else:
                                    pass
                        else:
                            pass
#                         commentRating=commentList.select('div[class="ui_column is-9"] span')[0]['class'][1].split('bubble_')[-1]
#                         commentTitle=commentList.select('span[class="noQuotes"]')[0].text
#                         comment=commentList.select('p[class="partial_entry"]')[0].text
#                         print(restName)
#                         print(commenter)
#                         print(str(int(commentRating)/10))
#                         print(commentTitle)
#                         print(comment)
#                         print('------')
#                         with open('./restComments/{}.txt'.format(restName), 'a', encoding='utf-8') as f:
#                             f.write('評論帳號: '+commenter+'\n')
#                             f.write('評論分數: '+str(int(commentRating)/10)+'\n')
#                             f.write('評論標題: '+commentTitle+'\n')
#                             f.write('評論內容: '+comment+'\n')
#                             f.write('------'+'\n')
                    newRestUrl='https://www.tripadvisor.com.tw'+restSoup.select('a[class="nav next ui_button primary"]')[0]['href']
                    restUrl=newRestUrl
                    print('***Click 手動載入，' + restName + '留言第' + str(k+1) + '頁***')    
                    k=k+1
                    time.sleep(random.randint(4, 6))
                except:
                    k=0
                    print(restName + 'has no more comments')                        
        except IndexError:
            print(IndexError)
            break
        time.sleep(random.randint(1, 5))
        
    newUrl = 'https://www.tripadvisor.com'+soup.select('a[class="nav next rndBtn ui_button primary taLnk"]')[0]['href']
    url=newUrl
    
browser.close()
# Out:
# *****LCK_of_Taiwan
# 新加坡柏偉詩酒店
#
# 50
# Top choice at Clark Quay
# One of the best mid-range hotels you can get at Clark Quay.
# With the price range and location of furama city while much more newly built, Park Regis boasts of s...
# https://www.tripadvisor.com.tw/Hotel_Review-g294265-d1935912-Reviews-Park_Regis_Singapore-Singapore.html
# ------
# ***Click 手動載入，W XYZ Bar留言第2頁***
# *****lend505050
# *****ACloud33
# *****rosivdapirtylla
# 紫艷中餐廳
#
# 50
# 好美好吃服務超讚的中餐廳
# 第一次來紫豔，每道菜色都好用心，服務貼心周到，大推烤鴨、春風得意腸粉，脆皮金磚黑毛豬燒肉好脆不膩，Allen 和另一位漂亮姐姐服務超好，雖然很忙還是一直來加茶，辛苦了。紫豔很讚！會再來的。
# https://www.tripadvisor.com.tw/Restaurant_Review-g13808515-d2202371-Reviews-Yen_Chinese_Restaurant-Xinyi_District_Taipei.html
# ------
# *****EverJennyT
# Kooks
#
# 50
# 台灣最有特色的美式餐廳
# 最愛漢堡～口味多樣，份量足，麵包可選芝麻麵包或拖鞋麵包，我個人偏愛拖鞋麵包，配餐也可選薯條或洋蔥圈或沙拉，每次來都超級滿足的！！另外Pita也是超有特色的～～常讓我有選擇困難啊！！！
# https://www.tripadvisor.com.tw/Restaurant_Review-g13806921-d3775798-Reviews-Kooks-Tamsui_New_Taipei.html
# ------
# Burger King Leicester Square
#
# 40
# 好滿足大漢堡
# 在這邊吃到小時候吃到的美味，雞排漢堡跟小時候吃到的一模一樣啊!!!~超級懷念~回國前一晚又跑來點了牛排漢堡，比華堡還好吃，真是太美味了!!可惜台灣都吃到不這些口味~~
# https://www.tripadvisor.com.tw/Restaurant_Review-g186338-d804929-Reviews-Burger_King_Leicester_Square-London_England.html
# ------
# 好小子擔仔麵
#
# 50
# 超好吃的消夜
# 這間看起來不太大的小店面，卻每次來都滿滿的人潮~我最愛點滷肉飯和沙茶牛肉，都是念念不忘的美食，每次幾乎都是必點的，另外還有紅燒肉、炸豆腐，搭配擔擔麵，也是非常簡單又美味的一餐。
# https://www.tripadvisor.com.tw/Restaurant_Review-g13806759-d6139236-Reviews-Hao_Xiao_Zi_Dan_Zai_Noodles-Nantun_Taichung.html
# ------
# 旅樂序精品旅館-站前三館
#
# 40
# 交通便利
# 旅館在火車站附近，周邊都是餐廳和逛街的地方，是非常適合來玩的旅客，還有免費的早餐自助吧，是斜對面的義式餐廳，好吃~~住三館還會提供免費的義式咖啡喔!!
# https://www.tripadvisor.com.tw/Hotel_Review-g13808853-d8493751-Reviews-Hotel_Relax_3-Zhongzheng_District_Taipei.html
# ------
# 台北北門世民酒店
#
# 50
# 非常喜歡，舒服又很有特色
# 非常喜歡，一進大廳就充滿科技感，全自動的checkin系統，如果不會操作，現場還有工作人員協助；二樓的客廳也很舒服，還有泡麵吧，可以在半夜餓的時候來吃點熱湯，自己愛加甚麼料就加甚麼料~當然房間是最愛，幾乎都是全白的色調，非常舒服，床超級好睡，還有超大的窗戶可以看到市景，浴室裡的洗髮精沐浴乳味道也很溫柔，好想帶回家喔!!...
